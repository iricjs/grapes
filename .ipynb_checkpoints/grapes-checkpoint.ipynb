# %%
# imports
import pandas as pd
import requests
import numpy as np
import re
from bs4 import BeautifulSoup
import datetime

# pandas settings
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# create empty dataframe
all_data = pd.DataFrame(index=[], columns=['Varietal','Type','Appellation','Qty','Price','Date','Listing_ID'])

# %%
# find final record and set maximum page
URL = "https://www.winebusiness.com/classifieds/grapesbulkwine/?sort_type=1&sort_order=desc&start=1#anchor1"
res = requests.get(URL)
soup = BeautifulSoup(res.content,'lxml')
searched_word = 'Results'
find_string = soup.body.find(text=re.compile(searched_word), recursive=True)
def largestNumber(in_str):
    l=[int(x) for x in in_str.split() if x.isdigit()]
    return max(l) if l else None
max_result = largestNumber(find_string)
page_max = ((int(max_result/50))*50)+2

# check max result to verify correct number of records
listings_found = str(max_result)
print('Listings found = ' + listings_found)
# Out:
# Listings found = 785

# %%
#Create loop through URL's
for i in range(1,page_max,50):
    # Set URL
    URL = "https://www.winebusiness.com/classifieds/grapesbulkwine/?sort_type=1&sort_order=desc&start={}#anchor1".format(i)
    res = requests.get(URL)
    soup = BeautifulSoup(res.content,'lxml')

    # Define specific table
    table = soup.find("table", attrs={"class": "table wb-cl-table"})
    df = pd.read_html(str(table))[0]

    # Add Listing_ID's
    tbody = table.find("tbody")
    df['Listing_ID'] = [np.where(tag.has_attr('href'),tag.get('href'),"no link") for tag in tbody.find_all('a')]
    
    #Create output table
    all_data = pd.concat([all_data, df], ignore_index=True)
    
listings_scraped = str(len(all_data))
print('Listings scraped = ' + listings_scraped)
# Out:
# Listings scraped = 785

# %%
if int(listings_found) - int(listings_scraped) == 0:
    print('No errors detected')
else:
    print('ERROR FOUND: listings scraped does not equal listings found')
# Out:
# No errors detected

# %%
#Add datestamp
now = datetime.datetime.now()
datestamp = now.strftime("%Y-%m-%d %H:%M:%S")
all_data['Datestamp'] = datestamp
all_data

# %%
# Create copy for analysis
df = all_data.copy()

#Filter on grapes only
    #is_grapes =  df['Type']=='Grapes'
    #df['Grapes'] = is_grapes
df = df[(df['Type']=='Grapes')]

#Create State column and filter on California
df['State'] = df['Appellation'].str[:2]
df = df[(df['State']=='CA')]

#Remove state from appellation values
df['Appellation'] = df['Appellation'].str[5:]

#Filter certain varietals
df = df[df['Varietal'].str.contains("Cabernet Sauvignon|Merlot|Pinot Noir|Chardonnay|Sauvignon Blanc", case=False)]
df = df[~df['Varietal'].str.contains("Sold", case=False)]

#Remove nulls from price and quantity and cast as float
df = df[df['Qty'].notna()]
NewQty = df['Qty'].str.extract('(\d*\.\d+|\d+)', expand=False).astype(float)
df = df[df['Price'].notna()]
NewPrice = df['Price'].str.extract('(\d*\.\d+|\d+)', expand=False).astype(float)
df['Tons'] = NewQty
df['$/Ton'] = NewPrice

#Add total cost
TotalCost = NewQty * NewPrice
df['Total Cost'] = TotalCost
# Out:
#                    Varietal    Type                           Appellation  \
# 0            '20 Pinot Noir  Grapes                         Sonoma County
# 1            '20 Pinot Noir  Grapes                  Russian River Valley
# 2            '20 Chardonnay  Grapes                  Russian River Valley
# 3            '20 Chardonnay  Grapes                  Russian River Valley
# 4            '20 Chardonnay  Grapes                  Russian River Valley
# 5    '20 Cabernet Sauvignon  Grapes                             Calistoga
# 11   '20 Cabernet Sauvignon  Grapes     Oak Knoll District of Napa Valley
# 16   '20 Cabernet Sauvignon  Grapes                           Coombsville
# 21      '20 Sauvignon Blanc  Grapes                      Creston District
# 22   '20 Cabernet Sauvignon  Grapes                      Creston District
# 26           '20 Chardonnay  Grapes                      Creston District
# 84   '20 Cabernet Sauvignon  Grapes                             Mendocino
# 89           '20 Pinot Noir  Grapes                           Arroyo Seco
# 119          '20 Pinot Noir  Grapes                  Russian River Valley
# 122  '20 Cabernet Sauvignon  Grapes                      Sierra Foothills
# 152          '20 Chardonnay  Grapes                           Coombsville
# 153              '20 Merlot  Grapes                           Coombsville
# 155     '20 Sauvignon Blanc  Grapes                            Yountville
# 158          '20 Chardonnay  Grapes                           Coombsville
# 159              '20 Merlot  Grapes                           Coombsville
# 161     '20 Sauvignon Blanc  Grapes                            Yountville
# 164          '20 Pinot Noir  Grapes                       Sta. Rita Hills
# 169          '20 Chardonnay  Grapes                       Sta. Rita Hills
# 180     '20 Sauvignon Blanc  Grapes                   Contra Costa County
# 215          '20 Pinot Noir  Grapes                   Yorkville Highlands
# 216              '20 Merlot  Grapes                         Sonoma Valley
# 219          '20 Chardonnay  Grapes                          Sonoma Coast
# 220          '20 Pinot Noir  Grapes                          Sonoma Coast
# 255     '20 Sauvignon Blanc  Grapes                  Russian River Valley
# 256          '20 Pinot Noir  Grapes                  Russian River Valley
# 263  '20 Cabernet Sauvignon  Grapes                   Yorkville Highlands
# 355  '20 Cabernet Sauvignon  Grapes                             Calistoga
# 356          '20 Pinot Noir  Grapes                San Luis Obispo County
# 392          '20 Pinot Noir  Grapes                  Russian River Valley
# 404  '20 Cabernet Sauvignon  Grapes                            Yountville
# 409          '20 Pinot Noir  Grapes                  Russian River Valley
# 459          '20 Pinot Noir  Grapes  Green Valley of Russian River Valley
# 480          '20 Pinot Noir  Grapes                          Los Carneros
# 528  '20 Cabernet Sauvignon  Grapes                         Sonoma Valley
# 529              '20 Merlot  Grapes                       Sonoma Mountain
# 531              '20 Merlot  Grapes                         Sonoma Valley
# 532  '20 Cabernet Sauvignon  Grapes                         Sonoma Valley
# 548     '20 Sauvignon Blanc  Grapes                            Clarksburg
# 558          '20 Chardonnay  Grapes                         Sonoma Valley
# 569          '20 Pinot Noir  Grapes                  Russian River Valley
# 585  '20 Cabernet Sauvignon  Grapes                    San Antonio Valley
# 628              '20 Merlot  Grapes                        Redwood Valley
# 735  '20 Cabernet Sauvignon  Grapes                       Mokelumne River
# 751          '20 Pinot Noir  Grapes                          Los Carneros
# 752          '20 Chardonnay  Grapes                         Sonoma Valley
# 753          '20 Pinot Noir  Grapes                          Los Carneros
#
#          Qty      Price   Date  \
# 0      7 ton  $2900/ton  05/25
# 1      5 ton  $2900/ton  05/25
# 2     15 ton  $1900/ton  05/25
# 3      5 ton  $1900/ton  05/25
# 4    150 ton  $1500/ton  05/25
# 5     30 ton  $4000/ton  05/25
# 11    10 ton  $4900/ton  05/24
# 16    30 ton  $5500/ton  05/23
# 21     2 ton  $1200/ton  05/22
# 22    25 ton  $1500/ton  05/22
# 26     8 ton  $1350/ton  05/22
# 84    90 ton  $2100/ton  05/20
# 89    20 ton  $2000/ton  05/19
# 119    8 ton  $3800/ton  05/18
# 122    8 ton  $1200/ton  05/18
# 152   15 ton  $3000/ton  05/18
# 153   15 ton  $3900/ton  05/18
# 155   15 ton  $2500/ton  05/18
# 158   15 ton  $3000/ton  05/18
# 159   15 ton  $3900/ton  05/18
# 161   15 ton  $2500/ton  05/18
# 164   20 ton  $2750/ton  05/18
# 169   15 ton  $2300/ton  05/18
# 180    6 ton  $1350/ton  05/18
# 215   10 ton  $3200/ton  05/15
# 216   10 ton  $2200/ton  05/15
# 219   20 ton  $2000/ton  05/14
# 220   50 ton  $2200/ton  05/14
# 255   10 ton  $3000/ton  05/14
# 256   10 ton  $4000/ton  05/14
# 263    6 ton  $2000/ton  05/14
# 355   20 ton  $5500/ton  05/11
# 356    1 ton  $2000/ton  05/11
# 392  120 ton  $2950/ton  05/10
# 404   60 ton  $6500/ton  05/08
# 409    5 ton  $5400/ton  05/08
# 459   10 ton  $4000/ton  05/07
# 480   10 ton  $3950/ton  05/06
# 528   80 ton  $2400/ton  05/05
# 529   12 ton  $1500/ton  05/05
# 531  100 ton  $1200/ton  05/05
# 532    8 ton  $2500/ton  05/05
# 548   40 ton   $750/ton  05/04
# 558   16 ton  $2200/ton  05/04
# 569    8 ton  $3200/ton  05/01
# 585   15 ton  $2000/ton  05/01
# 628   20 ton  $1400/ton  04/28
# 735    3 ton   $700/ton  04/22
# 751   15 ton  $3950/ton  04/22
# 752   10 ton  $2414/ton  04/22
# 753   17 ton  $2773/ton  04/22
#
#                                                    Listing_ID  \
# 0    /classifieds/grapesbulkwine/?go=listing&listingid=192009
# 1    /classifieds/grapesbulkwine/?go=listing&listingid=192010
# 2    /classifieds/grapesbulkwine/?go=listing&listingid=192005
# 3    /classifieds/grapesbulkwine/?go=listing&listingid=192006
# 4    /classifieds/grapesbulkwine/?go=listing&listingid=192007
# 5    /classifieds/grapesbulkwine/?go=listing&listingid=192000
# 11   /classifieds/grapesbulkwine/?go=listing&listingid=191992
# 16   /classifieds/grapesbulkwine/?go=listing&listingid=191978
# 21   /classifieds/grapesbulkwine/?go=listing&listingid=191961
# 22   /classifieds/grapesbulkwine/?go=listing&listingid=191962
# 26   /classifieds/grapesbulkwine/?go=listing&listingid=191966
# 84   /classifieds/grapesbulkwine/?go=listing&listingid=191812
# 89   /classifieds/grapesbulkwine/?go=listing&listingid=191791
# 119  /classifieds/grapesbulkwine/?go=listing&listingid=191722
# 122  /classifieds/grapesbulkwine/?go=listing&listingid=191713
# 152  /classifieds/grapesbulkwine/?go=listing&listingid=191677
# 153  /classifieds/grapesbulkwine/?go=listing&listingid=191678
# 155  /classifieds/grapesbulkwine/?go=listing&listingid=191680
# 158  /classifieds/grapesbulkwine/?go=listing&listingid=191671
# 159  /classifieds/grapesbulkwine/?go=listing&listingid=191672
# 161  /classifieds/grapesbulkwine/?go=listing&listingid=191674
# 164  /classifieds/grapesbulkwine/?go=listing&listingid=191668
# 169  /classifieds/grapesbulkwine/?go=listing&listingid=191661
# 180  /classifieds/grapesbulkwine/?go=listing&listingid=191644
# 215  /classifieds/grapesbulkwine/?go=listing&listingid=191577
# 216  /classifieds/grapesbulkwine/?go=listing&listingid=191574
# 219  /classifieds/grapesbulkwine/?go=listing&listingid=191556
# 220  /classifieds/grapesbulkwine/?go=listing&listingid=191557
# 255  /classifieds/grapesbulkwine/?go=listing&listingid=191490
# 256  /classifieds/grapesbulkwine/?go=listing&listingid=191491
# 263  /classifieds/grapesbulkwine/?go=listing&listingid=191479
# 355  /classifieds/grapesbulkwine/?go=listing&listingid=191270
# 356  /classifieds/grapesbulkwine/?go=listing&listingid=191266
# 392  /classifieds/grapesbulkwine/?go=listing&listingid=191214
# 404  /classifieds/grapesbulkwine/?go=listing&listingid=191198
# 409  /classifieds/grapesbulkwine/?go=listing&listingid=191174
# 459  /classifieds/grapesbulkwine/?go=listing&listingid=191116
# 480  /classifieds/grapesbulkwine/?go=listing&listingid=191070
# 528  /classifieds/grapesbulkwine/?go=listing&listingid=190998
# 529  /classifieds/grapesbulkwine/?go=listing&listingid=190997
# 531  /classifieds/grapesbulkwine/?go=listing&listingid=191000
# 532  /classifieds/grapesbulkwine/?go=listing&listingid=190995
# 548  /classifieds/grapesbulkwine/?go=listing&listingid=190940
# 558  /classifieds/grapesbulkwine/?go=listing&listingid=190925
# 569  /classifieds/grapesbulkwine/?go=listing&listingid=190904
# 585  /classifieds/grapesbulkwine/?go=listing&listingid=190870
# 628  /classifieds/grapesbulkwine/?go=listing&listingid=190761
# 735  /classifieds/grapesbulkwine/?go=listing&listingid=190578
# 751  /classifieds/grapesbulkwine/?go=listing&listingid=190553
# 752  /classifieds/grapesbulkwine/?go=listing&listingid=190554
# 753  /classifieds/grapesbulkwine/?go=listing&listingid=190555
#
#                Datestamp State   Tons   $/Ton  Total Cost
# 0    2020-05-25 16:06:11    CA    7.0  2900.0     20300.0
# 1    2020-05-25 16:06:11    CA    5.0  2900.0     14500.0
# 2    2020-05-25 16:06:11    CA   15.0  1900.0     28500.0
# 3    2020-05-25 16:06:11    CA    5.0  1900.0      9500.0
# 4    2020-05-25 16:06:11    CA  150.0  1500.0    225000.0
# 5    2020-05-25 16:06:11    CA   30.0  4000.0    120000.0
# 11   2020-05-25 16:06:11    CA   10.0  4900.0     49000.0
# 16   2020-05-25 16:06:11    CA   30.0  5500.0    165000.0
# 21   2020-05-25 16:06:11    CA    2.0  1200.0      2400.0
# 22   2020-05-25 16:06:11    CA   25.0  1500.0     37500.0
# 26   2020-05-25 16:06:11    CA    8.0  1350.0     10800.0
# 84   2020-05-25 16:06:11    CA   90.0  2100.0    189000.0
# 89   2020-05-25 16:06:11    CA   20.0  2000.0     40000.0
# 119  2020-05-25 16:06:11    CA    8.0  3800.0     30400.0
# 122  2020-05-25 16:06:11    CA    8.0  1200.0      9600.0
# 152  2020-05-25 16:06:11    CA   15.0  3000.0     45000.0
# 153  2020-05-25 16:06:11    CA   15.0  3900.0     58500.0
# 155  2020-05-25 16:06:11    CA   15.0  2500.0     37500.0
# 158  2020-05-25 16:06:11    CA   15.0  3000.0     45000.0
# 159  2020-05-25 16:06:11    CA   15.0  3900.0     58500.0
# 161  2020-05-25 16:06:11    CA   15.0  2500.0     37500.0
# 164  2020-05-25 16:06:11    CA   20.0  2750.0     55000.0
# 169  2020-05-25 16:06:11    CA   15.0  2300.0     34500.0
# 180  2020-05-25 16:06:11    CA    6.0  1350.0      8100.0
# 215  2020-05-25 16:06:11    CA   10.0  3200.0     32000.0
# 216  2020-05-25 16:06:11    CA   10.0  2200.0     22000.0
# 219  2020-05-25 16:06:11    CA   20.0  2000.0     40000.0
# 220  2020-05-25 16:06:11    CA   50.0  2200.0    110000.0
# 255  2020-05-25 16:06:11    CA   10.0  3000.0     30000.0
# 256  2020-05-25 16:06:11    CA   10.0  4000.0     40000.0
# 263  2020-05-25 16:06:11    CA    6.0  2000.0     12000.0
# 355  2020-05-25 16:06:11    CA   20.0  5500.0    110000.0
# 356  2020-05-25 16:06:11    CA    1.0  2000.0      2000.0
# 392  2020-05-25 16:06:11    CA  120.0  2950.0    354000.0
# 404  2020-05-25 16:06:11    CA   60.0  6500.0    390000.0
# 409  2020-05-25 16:06:11    CA    5.0  5400.0     27000.0
# 459  2020-05-25 16:06:11    CA   10.0  4000.0     40000.0
# 480  2020-05-25 16:06:11    CA   10.0  3950.0     39500.0
# 528  2020-05-25 16:06:11    CA   80.0  2400.0    192000.0
# 529  2020-05-25 16:06:11    CA   12.0  1500.0     18000.0
# 531  2020-05-25 16:06:11    CA  100.0  1200.0    120000.0
# 532  2020-05-25 16:06:11    CA    8.0  2500.0     20000.0
# 548  2020-05-25 16:06:11    CA   40.0   750.0     30000.0
# 558  2020-05-25 16:06:11    CA   16.0  2200.0     35200.0
# 569  2020-05-25 16:06:11    CA    8.0  3200.0     25600.0
# 585  2020-05-25 16:06:11    CA   15.0  2000.0     30000.0
# 628  2020-05-25 16:06:11    CA   20.0  1400.0     28000.0
# 735  2020-05-25 16:06:11    CA    3.0   700.0      2100.0
# 751  2020-05-25 16:06:11    CA   15.0  3950.0     59250.0
# 752  2020-05-25 16:06:11    CA   10.0  2414.0     24140.0
# 753  2020-05-25 16:06:11    CA   17.0  2773.0     47141.0

# %%
table1 = pd.pivot_table(df, values=['Tons', 'Total Cost'],
                     index=['Varietal'],aggfunc=np.sum, margins=False)

table1['$/Ton'] = table1['Total Cost'] / table1['Tons']

#Format Numbers
table1['Tons'] = table1['Tons'].map('{:,.1f}'.format)
table1['Total Cost'] = table1['Total Cost'].map('${:,.0f}'.format)
table1['$/Ton'] = table1['$/Ton'].map('${:,.0f}'.format)

#Sort
table1 = table1.sort_values(by=['$/Ton'], ascending=False)

#Reorder Columns
table1.columns = ['Tons Available', 'Total Value', 'Avg $/Ton']

#Print
table1

# %%
#Create pivot table2
table2 = pd.pivot_table(df[df.Varietal == "'20 Cabernet Sauvignon"], values=['Tons', 'Total Cost'],
                     index=['Appellation'],aggfunc=np.sum, margins=False)

#Create avg price per ton column
table2['$/Ton'] = table2['Total Cost'] / table2['Tons']

#Sort by avg price
table2 = table2.sort_values(by=['$/Ton'], ascending=False)

#Format numbers
table2['Tons'] = table2['Tons'].map('{:,.1f}'.format)
table2['Total Cost'] = table2['Total Cost'].map('${:,.0f}'.format)
table2['$/Ton'] = table2['$/Ton'].map('${:,.0f}'.format)

#print
table2

# %%
#Export to Excel
import os
username = os.getlogin()
#all_data.to_excel(f'C:\\Users\\{username}\\Desktop\\grape_data.xlsx', index = False)

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter(f'C:\\Users\\{username}\\Desktop\\Grape_Data.xlsx', engine='xlsxwriter')

# Write each dataframe to a different worksheet.
table1.to_excel(writer, sheet_name='Summary')
table2.to_excel(writer, sheet_name='Cab Sauv by App')
all_data.to_excel(writer, sheet_name='Raw Data')

# Close the Pandas Excel writer and output the Excel file.
writer.save()
